# %%
import pandas as pd

# %%
df = pd.read_csv('cycling-activities.csv')
df
# Out:
#     Activity Type             Date  Favorite                           Title  \
# 0    Road Cycling   8/27/2022 9:44     False                 Trento and back
# 1    Road Cycling  8/24/2022 10:09     False      Mittelberg + Passo Mendola
# 2    Road Cycling   8/22/2022 8:41     False               Mittelberg 2022_3
# 3    Road Cycling   8/13/2022 9:24     False  🚴‍♂️🚴‍♀️Passeiertal with Karin
# 4    Road Cycling  8/11/2022 16:38     False               Mittelberg 2022_2
# ..            ...              ...       ...                             ...
# 748       Cycling  7/29/2012 10:16     False               Černá Hora circle
# 749       Cycling   7/9/2012 19:46     False                        Berghaus
# 750       Cycling    7/5/2012 9:08     False         Z chaty do Monkey Parku
# 751       Cycling   7/4/2012 20:08     False            Z Horizontu do chaty
# 752       Cycling   7/4/2012 13:24     False                      Okolo Pece
#
# ...

# %%
# Cleaning table from unsued columns

df = df.drop(columns=[
'Favorite',
'Avg Run Cadence',
'Max Run Cadence',
'Avg Stride Length', 
'Avg Vertical Ratio',
'Avg Vertical Oscillation', 
'Avg Ground Contact Time',
'Grit', 
'Flow',
'Avg. Swolf',
'Avg Stroke Rate', 
'Total Reps', 
'Dive Time',
'Surface Interval', 
'Decompression', 
'Best Lap Time', 
'Number of Laps',
'Max Temp']
)

# %%
df.dtypes
# Out:
# Activity Type              object
# Date                       object
# Title                      object
# Distance                   object
# Calories                   object
# Time                       object
# Avg HR                     object
# Max HR                     object
# Aerobic TE                 object
# Avg Speed                  object
# Max Speed                  object
# Total Ascent               object
# Total Descent              object
# Avg Bike Cadence           object
# Max Bike Cadence           object
# Normalized Power® (NP®)    object
# Training Stress Score®     object
# Max Avg Power (20 min)     object
# Avg Power                  object
# Max Power                  object
# Total Strokes              object
# Min Temp                   object
# Moving Time                object
# Elapsed Time               object
# Min Elevation              object
# Max Elevation              object
# dtype: object

# %%
df['Distance'].replace(',', '.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8096/298394519.py in <module>
# ----> 1 df['Distance'].astype('int64')
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\Python310\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...
